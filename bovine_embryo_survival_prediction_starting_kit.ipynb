# %% [markdown]
# <div>
# <table style="width:100%; background-color:transparent;">
#   <tr style="background-color:transparent;">
#     <td align="left"; style="background-color:transparent; width: 33%;"><a href="https://www.inrae.fr"><img src="https://www.inrae.fr/themes/custom/inrae_socle/logo.svg" width="40%"></a></td>
#     <td align="center"; style="background-color:transparent; width: 33%;"><a href = "https://dataia.eu/"><img src="https://github.com/ramp-kits/bovine_embryo_survival_prediction/raw/main/DATAIA-h.png" width="80%"></a></td>
#     <td align="right"; style="background-color:transparent; width: 33%;"><a href="https://www.vet-alfort.fr/"><img src="https://www.vet-alfort.fr/images/logo-enva.svg" width="55%"></a></td>
#   </tr>
# </table>
# </div>
#
# <center><h1>Bovine Embryos Movies challenge</h1></center>
#
# <center><h3>A data challenge on early prediction of the fate of bovine embryos</h3></center>
# <br/>
# <center><i>Julien Chiquet (MIA Paris-Saclay, Inrae), Pierre Gloaguen (MIA Paris-Saclay, AgroParisTech), Nicolas Jouvin (MIA Paris-Saclay), Patrick Bouthemy (SERPICO, Inria), Alain Truibil (MaiAGE, Inrae), Alline Reis (PASP, ENVA), François Caud, Alexandre Gramfort (DATAIA, Univ. Paris-Saclay) </i></center>

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# This challenge consists in predicting the developmental state of bovine embryos seen at 8 days after fertilisation (daf). There are 8 different classes (denoted from "A" to "H" in this challenge) corresponding to biological states from alive ("A") to dead ("H").
#
# The known labels are the developmental state of the embryos at 8 daf, however, it is of great interest to be able to predict this future state as early as possible. The goal of this challenge is to predict these states between 1 and 4 daf (at latest) and to be as precise as possible to the indicated labels. For this, you have access to 277 videos from our own database (INRAE) each one composed of 300 snapshots taken every fifteen minutes.
#
# *Note:* Due to experimental conditions, the first snapshot was made at a time t0 ($t_0$) that might vary between videos. The timestamp information of each frame in each video is available and accessible. The predicting model will aim at predicting at specific *times* (and not frame numbers).
#
# *Note:* Any communication from this challenge must be authorized by the owners of the Database before publication.

# %% [markdown]
# ## Setup
#
# ### Prerequisites
#
# The following cell will install the required package dependencies, if necessary. You can examine the file, `requirements.txt`, included in the repo to view the list of dependencies.

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Collecting ramp-workflow
#   Using cached ramp_workflow-0.5.0-py3-none-any.whl (130 kB)
# Collecting osfclient
#   Using cached osfclient-0.0.5-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: numpy in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 6)) (1.22.3)
# Requirement already satisfied: scipy in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 7)) (1.7.3)
# Requirement already satisfied: pandas in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 9)) (3.5.1)
# Requirement already satisfied: seaborn in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 10)) (0.11.2)
# Requirement already satisfied: jupyter in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: scikit-learn in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 13)) (1.0.2)
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
# Collecting flake8
#   Downloading flake8-4.0.1-py2.py3-none-any.whl (64 kB)
# Requirement already satisfied: black in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 18)) (22.3.0)
# Requirement already satisfied: cloudpickle in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 21)) (2.0.0)
# Requirement already satisfied: pyyaml in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from -r requirements.txt (line 22)) (6.0)
# Requirement already satisfied: joblib in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ramp-workflow->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: click in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ramp-workflow->-r requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: six in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from osfclient->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: requests in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from osfclient->-r requirements.txt (line 3)) (2.27.1)
# Collecting tqdm
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from matplotlib->-r requirements.txt (line 9)) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from matplotlib->-r requirements.txt (line 9)) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from matplotlib->-r requirements.txt (line 9)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from matplotlib->-r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from matplotlib->-r requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from matplotlib->-r requirements.txt (line 9)) (3.0.4)
# Requirement already satisfied: jupyter-console in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter->-r requirements.txt (line 11)) (6.4.3)
# Requirement already satisfied: qtconsole in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter->-r requirements.txt (line 11)) (5.3.0)
# Requirement already satisfied: ipywidgets in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter->-r requirements.txt (line 11)) (7.6.5)
# Requirement already satisfied: nbconvert in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter->-r requirements.txt (line 11)) (6.4.4)
# Requirement already satisfied: ipykernel in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter->-r requirements.txt (line 11)) (6.9.1)
# Requirement already satisfied: notebook in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter->-r requirements.txt (line 11)) (6.4.11)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from scikit-learn->-r requirements.txt (line 13)) (2.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (1.46.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (1.14.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (2.9.0)
# Requirement already satisfied: setuptools in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (61.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (14.0.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (0.26.0)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (1.12)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (4.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorflow-gpu->-r requirements.txt (line 14)) (3.6.0)
# Collecting pycodestyle<2.9.0,>=2.8.0
#   Downloading pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pyflakes<2.5.0,>=2.4.0
#   Downloading pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: platformdirs>=2 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from black->-r requirements.txt (line 18)) (2.5.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from black->-r requirements.txt (line 18)) (0.4.3)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from black->-r requirements.txt (line 18)) (2.0.1)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from black->-r requirements.txt (line 18)) (0.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu->-r requirements.txt (line 14)) (0.37.1)
# Requirement already satisfied: colorama in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from click->ramp-workflow->-r requirements.txt (line 2)) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (2.1.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (2.6.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (3.3.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (5.1.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from requests->osfclient->-r requirements.txt (line 3)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from requests->osfclient->-r requirements.txt (line 3)) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from requests->osfclient->-r requirements.txt (line 3)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from requests->osfclient->-r requirements.txt (line 3)) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow-gpu->-r requirements.txt (line 14)) (3.2.0)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 11)) (1.5.5)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 11)) (8.3.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 11)) (7.2.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipykernel->jupyter->-r requirements.txt (line 11)) (6.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: backcall in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (3.0.20)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->-r requirements.txt (line 11)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->-r requirements.txt (line 11)) (4.10.0)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->-r requirements.txt (line 11)) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client<8.0->ipykernel->jupyter->-r requirements.txt (line 11)) (302)
# Requirement already satisfied: wcwidth in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (0.2.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 11)) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 11)) (5.3.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->-r requirements.txt (line 11)) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->-r requirements.txt (line 11)) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->-r requirements.txt (line 11)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter->-r requirements.txt (line 11)) (21.4.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 11)) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 11)) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 11)) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: jinja2 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from notebook->jupyter->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 11)) (0.8.4)
# Requirement already satisfied: bleach in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 11)) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 11)) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: testpath in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 11)) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 11)) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from jinja2->notebook->jupyter->-r requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->-r requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from argon2-cffi->notebook->jupyter->-r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r requirements.txt (line 11)) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->-r requirements.txt (line 11)) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 11)) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from bleach->nbconvert->jupyter->-r requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from qtconsole->jupyter->-r requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: asttokens in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (2.0.5)
# Requirement already satisfied: executing in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\jacobo\anaconda3\envs\bovine-gpu\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 11)) (0.2.2)
# Installing collected packages: protobuf, tqdm, pyflakes, pycodestyle, mccabe, tensorflow-gpu, ramp-workflow, osfclient, flake8
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
# Successfully installed flake8-4.0.1 mccabe-0.6.1 osfclient-0.0.5 protobuf-3.19.4 pycodestyle-2.8.0 pyflakes-2.4.0 ramp-workflow-0.5.0 tensorflow-gpu-2.9.1 tqdm-4.64.0

# %%
import numpy as np

# %% [markdown]
# > **NOTE:** Due to the structure of the challenge, libraries not included in `requirements.txt` will need to be added to be added via a pull request to the [GitHub repo](https://github.com/ramp-kits/bovinsembryos).

# %% [markdown]
# Install the `ramp-workflow` package from PyPI using the following command in you dedicated python environment.
#
# ```pip install ramp-workflow```

# %% [markdown]
# ### The problem.py file
#
# This file contains the definition of the data-challenge according to the RAMP framework. In addition, it contains some useful methods and class.

# %%
from problem import get_train_data, get_test_data, WeightedClassificationError

# %% [markdown]
# ## Downloading the data
#
# The public data are stored in a public OSF repository, you only need to run the following script which create the `data/` repository locally.
#
# > Note that, in order to be registered to the RAMP studio event, partiticipants must fill the [following form](https://framaforms.org/access-request-to-the-bovmovies2pred-data-challenge-osf-dataset-1646386323) which contain an agreement on the use of the data.
#
# ```python download_data.py```

# %%
# !python download_data.py
# Out:
# C:\Users\Jacobo\CS\RAMP-Server\ramp_deployment\ramp-kits\bovine_embryo_survival_prediction\data directory is not empty. Please empty it or select another destination for LOCAL_DATA if you wish to proceed

# %% [markdown]
# # Data exploration <a name=data_exp></a>
#
# ### Loading the data

# %% [markdown]
# First, we load the data using the utility function designed for the challenge in `problem.py`.

# %%
videos_train, labels_train = get_train_data()

# %% [markdown]
# `labels_trains` simply consists in the set of labels for the training set, stored as a `numpy.darray`

# %%
print(labels_train[:10])
print(labels_train.shape)
print('Number of videos in the training set: {}'.format(labels_train.size))
# Out:
# ['H' 'H' 'A' 'F' 'H' 'A' 'A' 'F' 'F' 'A']
# (177,)
# Number of videos in the training set: 177

# %% [markdown]
# On the other hand `videos_train` is a list of objects from the class `VideoReader`. This class is fully described below.

# %%
print(type(videos_train)) # List
print(type(videos_train[0])) # VideoReader object (see below)
# Out:
# <class 'list'>
# <class 'problem.VideoReader'>

# %% [markdown]
# ### Data visualization
#
# A video is timelapse of the embryos development, with one image every 15 minutes. One may plot a video image at a specific time (expressed in hour) via the `read_frame` helper method (described below).

# %%
import matplotlib.pyplot as plt
# Here, we use the read_frame method to extract a specific time
# See below for the description of this method
plt.imshow(videos_train[0].read_frame(frame_time=24), cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# One may also inspect the class distribution among the 8 possible categories

# %%
labs, counts = np.unique(labels_train, return_counts=True)
plt.bar(labs, counts)
plt.title("Barplot of class distribution in the train dataset")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44096/1844504623.py in <module>
# ----> 1 labs, counts = np.unique(labels_train, return_counts=True)
#       2 plt.bar(labs, counts)
#       3 plt.title("Barplot of class distribution in the train dataset")
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## The VideoReader class
#
# The `VideoReader` class aims at manipulating the videos. It is basically a wrapper for some openCV features of the library `cv2`, and its main aim is to ease the manipulation of videos for the participants. It is implemented in the `problem.py` file, still we copy its definition here for the sake of self-completeness.

# %%
# You can import the VideoReader class from problem.py via
from problem import VideoReader

# %%
import cv2

class VideoReader:
    def __init__(self, video_filename, frame_times, img_size=[250, 250]):
        self.video = cv2.VideoCapture(video_filename)
        self.nb_frames = int(self.video.get(cv2.CAP_PROP_FRAME_COUNT))
        self.img_size = img_size
        self.frame_times = frame_times

    def read_frame(self, frame_time):
        """Return the frame of a VideoReader object at the specified `frame_time`

        Args:
            frame_time (float): the specified time in hours (allowing quarter hours, e.g. 25.75 or 26.50)

        Raises:
            ValueError: If the specified time does not exist for the selected video

        Returns:
            np.ndarray: A 2-D array containing the grayscale image. 
        """
        if frame_time not in self.frame_times:
            raise ValueError('The specified frame time must me within the time '
                             'interval of the video.')

        frame_nb = np.where(self.frame_times == frame_time)[0][0]
        if frame_nb is not None:
            self.video.set(cv2.CAP_PROP_POS_FRAMES, frame_nb)
        _, frame = self.video.read()

        # always reset video's frame counter to 0 to avoid unexpected behavior
        self.video.set(cv2.CAP_PROP_POS_FRAMES, 0)

        return cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    def read_sequence(self, begin_time=None, end_time=None):
        """Extract the sequence of consecutive frames from begin_time to end_time (included)

        Args:
            begin_time (float, optional): The time where the extraction begins. Defaults to None.
            end_time (float, optional):  The time where the extraction ends. Defaults to None.

        Returns:
            np.ndarray: A 3-D numpy array with first axis corresponding to the frame index and the remaining dimension to image size.
        """
        if begin_time is None:
            begin_time = self.frame_times[0]
        elif begin_time not in self.frame_times:
            raise ValueError('The specified begin_time must me within the time'
                             ' interval of the video.')

        if end_time is None:
            end_time = self.frame_times[-1]
        elif end_time not in self.frame_times:
            raise ValueError('The specified end_time must me within the time '
                             'interval of the video.')

        if begin_time > end_time:
            raise ValueError("begin_time must be smaller than end_time.")

        begin_nb = np.where(self.frame_times == begin_time)[0][0]
        end_nb = np.where(self.frame_times == end_time)[0][0]
        self.video.set(cv2.CAP_PROP_POS_FRAMES, begin_nb)

        my_frames = list(range(begin_nb, end_nb + 1))
        video_array = np.empty(
            shape=(len(my_frames), self.img_size[0], self.img_size[1])
        )
        for t, _ in enumerate(my_frames):
            _, frame = self.video.read()
            video_array[t, :, :] = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # always reset video's frame counter to 0 to avoid unexpected behavior 
        self.video.set(cv2.CAP_PROP_POS_FRAMES, 0)

        return video_array

    def read_samples(self, selected_times=None):
        """Read several frames of the video at once corresponding to the selected times.

        Args:
            selected_times (list, optional): The list of of desired extraction times, in hours (allowing quarter hour). Defaults to None, the whole 300 frames are returned.

        Returns:
            np.ndarray: A 3-D numpy array with of shape (size len(selected_times), 250, 250).
        """
        if selected_times is None:
            selected_times = self.frame_times

        res = np.empty([len(selected_times), self.img_size[0], self.img_size[1]])
        frame_nbs = np.where([t in selected_times for t in self.frame_times])[0]
        for i, f in enumerate(frame_nbs):
            self.video.set(cv2.CAP_PROP_POS_FRAMES, f)
            _, frame = self.video.read()

            res[i, :, :] = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        self.video.set(cv2.CAP_PROP_POS_FRAMES, 0)

        return res

# %% [markdown]
# ### Attributes
#
# The `VideoReader` class has 3 attributes illustrated in the next cell :
# - `video`: the video object, which is as cv2.VideoCapture (see [the documentation](https://docs.opencv.org/3.4/d8/dfe/classcv_1_1VideoCapture.html))
# - `nb_frames`: the number of frames. This should be 300 for each video.
# - `frame_times`:  a 1-D `numpy.array` containing the times at which the frames where recorded. These times are expressed in hours since the fecondation. **All frames** are separated by 15 mns (0.25 hours). However, due to different experimental conditions, videos **might start at different times**!
# - `img_size` returns the dimensions of the square images composing the video. This should be normalized to $250 \times 250$.

# %%
example_video = videos_train[0]
print("A video is stored as a " + str(type(example_video.video)) + " Python object.")
print("It has " + str(example_video.nb_frames) + " frames of size " + str(example_video.img_size) + ".")
print("The frame are recorded at the following times (expressed as time in hour since the fecondation)")
print(example_video.frame_times[0:30])
# Out:
# A video is stored as a <class 'cv2.VideoCapture'> Python object.
# It has 300 frames of size [250, 250].
# The frame are recorded at the following times (expressed as time in hour since the fecondation)
# [23.75 24.   24.25 24.5  24.75 25.   25.25 25.5  25.75 26.   26.25 26.5
#  26.75 27.   27.25 27.5  27.75 28.   28.25 28.5  28.75 29.   29.25 29.5
#  29.75 30.   30.25 30.5  30.75 31.  ]

# %% [markdown]
# ### Methods
# The `VideoReader` class has methods illustrated in the next cell :
# - The `read_frame` method returns the frame of the video at a specified time.  The user must provide the `frame_time` argument, which is a time present in the `frame_times` attribute. This method returns a 2-D `numpy.ndarray`.
# - The `read_sequence` method returns a sequence of **consecutive frames**. The user must provide the `begin_time` argument (the frame time at which the sequence begins) and the `end_time` (the frame time at which the sequence ends). By default, these two arguments are set to `None`, which results in starting at first time and ending at last time. The method returns a 3-D ($n \times 250 \times 250$) `numpy.ndarray`, where $n$ is the number of consecutive times between `begin_time` and `end_time` (included).
# - The `read_samples` method transforms the video to a 3-D ($300 \times 250 \times 250$) `numpy.ndarray`. Optionally, a `selected_times` argument (provided as a list) may be specified to only select frames corresponding to these times.

# %%
example_video = videos_train[100]

# %%
selected_times = example_video.frame_times[[0,50,100,150,200,250,299]] 
print("Plot the videos frames corresponding to times: " + str(selected_times) + " hours.")
for frame_time in selected_times:
    plt.imshow(example_video.read_frame(frame_time), cmap="gray")
    plt.axis('off')
    plt.show()
# Out:
# Plot the videos frames corresponding to times: [22.25 34.75 47.25 59.75 72.25 84.75 97.  ] hours.

# %%
labels_train[100]
# Out:
# 'A'

# %%
video_array = example_video.read_sequence()
video_array.shape
# Out:
# (300, 250, 250)

# %%
image=video_array[0]

# %%
type(image[0][0])
# Out:
# numpy.float64

# %%
video_array = example_video.read_sequence(end_time = 29)
print(video_array.shape)

video_array = example_video.read_sequence(begin_time = 28.75, end_time=29)
print(video_array.shape)
# Out:
# (28, 250, 250)
# (2, 250, 250)

# %%
video_array = example_video.read_samples(selected_times=[23.75, 62.25, 96])
video_array.shape
# Out:
# (3, 250, 250)

# %% [markdown]
# > **Caution:** the VideoReader class does not load all the videos frame into memory, which is useful in order not to overload you local machine or the RAMP servers. However, the `read_sample` or `read_sequence` may quickly lead to memory issues when trying to load every video. You code should take this issue into account and treat videos sequentially or, at least, batch-wise.

# %%
# DO NOT TRY TO RUN (memory will collapse)
# data = []
# for video in videos_train:
#     data.append(data.read_samples())

# %% [markdown]
# # Designing a submission

# %% [markdown]
# ### Evaluation
#
# For the moment, we only consider the overall classification accuracy of your classifiers.
#
# Locally, the RAMP platform use a 3-fold cross-validation scheme implemented for you in the `get_cv` method. Moreover, the classifier's performance is evaluated on a separate test set which can be loaded just as the training data.

# %%
videos_test, labels_test  = get_test_data()

# %%
print('Number of subjects in the test set: {}'.format(labels_test.size))
# Out:
# Number of subjects in the test set: 100

# %% [markdown]
# ### Handling several prediction times
#
# Remember that the challenge's objective is to design classifier(s) for different prediction times between 1 and 4 days (24 to 96 hours). Your submission should account for that constraints with a `pred_time` argument for the model fit and prediction, ensuring that only frames up to `pred_times` are used for model training and testing.
#
# The predefined and fixed prediction times are

# %%
pred_times = [27, 32, 37, 40, 44, 48, 53, 58,  63, 94, None]

# %% [markdown]
# where `None` defaults to the use of the whole 300 frame for each video.
#
# > **Important:** You are freed to opt for having one model for each prediction time, or one model for every time. However, note that for the second option your model will be fully retrained at each prediction time, and that it must handle videos with a varying number of frames.

# %% [markdown]
# ### Mandatory structure of a submission
#
#
# A submission (usually stored in `./subsmissions/<submission_foldername>/`) must contain on file named `videoclassifier.py`.
#
# This python script must itself implement at least a `VideoClassifier` class with
#  * A `fit(videos, y, pred_time)` method.
#  * A `pred(videos, pred_time)` method.
#
# The two arguments must be understood as follow:
#  * `videos` is a list of `VideoReader` object with videos object cut at `pred_times`.
#  * `y` is a 1-D numpy array containing the associated training labels.
#  * `pred_time` is the time of development for which the prediction shall be made.
#
# We illustrate this below with a simple example.

# %% [markdown]
# ### Illustration : a dummy random classifier
#
# This classifier does not use (nor even load into memory) the videos or the prediction time, and just predict random labels. Still, it is a valid (albeit unuseful) submission regarding the RAMP workflow.
#
# It is implemented in the `./subsmissions/starting_kit/` folder and we copy its code here for illustration.

# %%
import numpy as np


class VideoClassifier(object):
    def __init__(self):
        pass

    def fit(self, videos: list, y, pred_time: float):
        classes = ["A", "B", "C", "D", "E", "F", "G", "H"]
        self.n_classes = len(classes)
        pass

    def predict(self, videos: list, pred_time: float):
        proba = np.random.rand(len(videos), self.n_classes)
        proba /= proba.sum(axis=1)[:, np.newaxis]
        return proba

# %%
my_pred_time = 94
my_model = VideoClassifier()
my_model.fit(videos_train, labels_train, pred_time=my_pred_time)
y_pred = my_model.predict(videos_test, pred_time=my_pred_time)

# %% [markdown]
# #### Score function
#
# For now, only weighted classification error is implemented. The LOWER the better. This score is based on weighted errors. The weights were determined by an expert.

# %%
def lett_to_num(y):
    """Return a numeric encoding of the letters"""
    return [ord(lab) - 65 for lab in y]

# %%
labels_test.shape
# Out:
# (100,)

# %%
y_pred[0]
# Out:
# array([0.06481163, 0.07320328, 0.24620966, 0.26564746, 0.0824302 ,
#        0.14765272, 0.05512963, 0.06491543])

# %%
wce = WeightedClassificationError(time_idx=my_pred_time)
wce.compute(y_true=lett_to_num(labels_test), y_pred=y_pred)
# Out:
# 0.679

# %%
for time_idx, my_pred_time in enumerate(pred_times):
    my_model = VideoClassifier()
    my_model.fit(videos_train, labels_train, pred_time=my_pred_time)
    y_pred = my_model.predict(videos_test, pred_time=my_pred_time)
    wce = WeightedClassificationError(time_idx=time_idx)
    print('Classification error at time ' + str(my_pred_time) + ' is:', str(wce.compute(y_true=lett_to_num(labels_test), y_pred=y_pred)))
# Out:
# Classification error at time 27 is: 0.7510000000000001
# Classification error at time 32 is: 0.778
# Classification error at time 37 is: 0.7509999999999999
# Classification error at time 40 is: 0.787
# Classification error at time 44 is: 0.779
# Classification error at time 48 is: 0.812
# Classification error at time 53 is: 0.737
# Classification error at time 58 is: 0.722
# Classification error at time 63 is: 0.7440000000000001
# Classification error at time 94 is: 0.7440000000000001
# Classification error at time None is: 0.8059999999999999

# %% [markdown]
# To compare to the performance of a (dummy) classifier, returning only one of the 8 classes

# %%
for cl in np.unique(labels_train):
    y_cl = np.zeros((labels_train.size, np.unique(labels_train).size))
    y_cl[:, lett_to_num(cl)] = 1
    print('Classifying all videos in class', cl, 'gives a score of:', wce.compute(lett_to_num(labels_train), y_cl))
# Out:
# Classifying all videos in class A gives a score of: 0.7457627118644068
# Classifying all videos in class B gives a score of: 0.7129943502824859
# Classifying all videos in class C gives a score of: 0.7192090395480226
# Classifying all videos in class D gives a score of: 0.8378531073446328
# Classifying all videos in class E gives a score of: 0.8112994350282487
# Classifying all videos in class F gives a score of: 0.7389830508474577
# Classifying all videos in class G gives a score of: 0.8203389830508474
# Classifying all videos in class H gives a score of: 0.6903954802259887

# %% [markdown]
# ### Submitting to RAMP
#
# Before submitting to RAMP, you can test your solution locally to ensure that trivial errors (e.g. typos, path issues, etc.) are resolved. We can test a given submission using the `ramp` command that was installed in the virtual environment.
# We'll use the following command:
# `!ramp test --submission <subm_folder> --quick-test`
# The `!` signals that the command should be run on the command line instead of this notebook.
# `ramp-test` is the command to be executed. It signals `ramp` to perform a local test.
# `--submission <subm_folder>` specifies which submission to run. You can have multiple potential submissions in the `submissions/` directory; this prevents `ramp` from running all of them.

# %%
# !ramp-test --submission starting_kit
# Out:
# Testing Bovine embryos survival prediction
# Reading train and test files from ./data/ ...
# RAMP TEST MODE 1111111111111111
# returning 177
# RAMP TEST MODE 1111111111111111
# returning 100
# RAMP TEST MODE 1111111111111111
# returning 177
# Reading cv ...
# Training submissions/starting_kit ...
# CV fold 0
# 	score  WeightedClassifErr[1]  WeightedClassifErr[2]  WeightedClassifErr[3]  WeightedClassifErr[4]  WeightedClassifErr[5]  WeightedClassifErr[6]  WeightedClassifErr[7]  WeightedClassifErr[8]  WeightedClassifErr[9]  WeightedClassifErr[10]  WeightedClassifErr[11]      time
# 	train                   0.75                   0.80                   0.74                   0.80                   0.79                   0.79                   0.77                   0.74                   0.79                    0.71                    0.77  0.010023
# 	valid                   0.77                   0.72                   0.84                   0.72                   0.74                   0.79                   0.77                   0.64                   0.74                    0.67                    0.70  0.011100
# 	test                    0.74                   0.71                   0.74                   0.73                   0.77                   0.79                   0.76                   0.72                   0.77                    0.76                    0.78  0.007837
# CV fold 1
# 	score  WeightedClassifErr[1]  WeightedClassifErr[2]  WeightedClassifErr[3]  WeightedClassifErr[4]  WeightedClassifErr[5]  WeightedClassifErr[6]  WeightedClassifErr[7]  WeightedClassifErr[8]  WeightedClassifErr[9]  WeightedClassifErr[10]  WeightedClassifErr[11]      time
# 	train                   0.82                   0.78                   0.70                   0.77                   0.79                   0.75                   0.73                   0.74                   0.72                    0.82                    0.73  0.012724
# 	valid                   0.77                   0.74                   0.75                   0.84                   0.76                   0.68                   0.74                   0.70                   0.80                    0.69                    0.68  0.015478
# 	test                    0.72                   0.79                   0.75                   0.77                   0.67                   0.78                   0.72                   0.74                   0.76                    0.73                    0.80  0.011569
# ----------------------------
# Mean CV scores
# ----------------------------
# 	score WeightedClassifErr[1] WeightedClassifErr[2] WeightedClassifErr[3] WeightedClassifErr[4] WeightedClassifErr[5] WeightedClassifErr[6] WeightedClassifErr[7] WeightedClassifErr[8] WeightedClassifErr[9] WeightedClassifErr[10] WeightedClassifErr[11]       time
# 	train          0.79 ± 0.035          0.79 ± 0.011          0.72 ± 0.017          0.79 ± 0.013          0.79 ± 0.001           0.77 ± 0.02          0.75 ± 0.022          0.74 ± 0.003          0.76 ± 0.035           0.77 ± 0.052            0.75 ± 0.02  0.0 ± 0.0
# 	valid            0.77 ± 0.0           0.73 ± 0.01           0.8 ± 0.044           0.78 ± 0.06           0.75 ± 0.01          0.73 ± 0.051          0.76 ± 0.014          0.67 ± 0.033          0.77 ± 0.032           0.68 ± 0.011           0.69 ± 0.013  0.0 ± 0.0
# 	test            0.73 ± 0.01          0.75 ± 0.036          0.75 ± 0.005           0.75 ± 0.02          0.72 ± 0.047          0.78 ± 0.003          0.74 ± 0.021          0.73 ± 0.008          0.76 ± 0.006           0.74 ± 0.017           0.79 ± 0.008  0.0 ± 0.0
# ----------------------------
# Bagged scores
# ----------------------------
# 	score  WeightedClassifErr[1]  WeightedClassifErr[2]  WeightedClassifErr[3]  WeightedClassifErr[4]  WeightedClassifErr[5]  WeightedClassifErr[6]  WeightedClassifErr[7]  WeightedClassifErr[8]  WeightedClassifErr[9]  WeightedClassifErr[10]  WeightedClassifErr[11]
# 	valid                   0.73                   0.73                   0.82                   0.76                   0.72                   0.72                   0.78                   0.66                   0.79                    0.67                    0.71
# 	test                    0.74                   0.80                   0.73                   0.73                   0.71                   0.77                   0.69                   0.77                   0.71                    0.73                    0.85

# %% [markdown]
# We can see that the results are not very good, but that is expected: our estimator in starting_kit completely ignores the data and returns a random prediction!
#
# RAMP will automatically perform 3-fold cross-validation and report the WeightedClassificationError for each of the folds and each prediction times, along with the mean across the folds. Bagging of the results has been disabled; the output can be ignored.

# %% [markdown]
# ## More information
#
# You can find more information in the [README](https://github.com/paris-saclay-cds/ramp-workflow/blob/master/README.md) of the [ramp-workflow library](https://github.com/paris-saclay-cds/ramp-workflow).
